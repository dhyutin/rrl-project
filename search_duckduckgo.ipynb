# %%
from duckduckgo_search import DDGS

def search_duckduckgo(query, num_results=5):
    with DDGS() as ddgs:
        results = list(ddgs.text(query, max_results=num_results))
        return results

query = "Give me details of hotels with 3 bedrooms and 2 bathrooms for 3 days. tHE HOTEL MUST ALSO FACE THE BEACH AND IS ALSO pet-friendly"
search_results = search_duckduckgo(query)

for i, result in enumerate(search_results, 1):
    print(f"{i}. {result['title']}\n   {result['href']}\n   {result['body']}\n")
    for
# Out:
# 1. Deluxe 3-Bedroom Oceanfront Hotel Suites | Acqualina Resort
#    https://www.acqualinaresort.com/accommodations/multi-bedroom-suites/deluxe-three-bedroom-oceanfront-hotel-suite
#    The 220 sq. ft. master bathrooms are outfitted with imported marble flooring, double sinks, custom vanity area, bathtub, and glass-enclosed couples shower. The family bedrooms feature a full private bathroom and two twin beds. The guest bedrooms feature a king bed and are adjacent to a full bathroom.
#
# 2. Beachfront Fireside Cottage - 3 Bedroom - Hotel del Coronado
#    https://hoteldel.com/stay/beach-village/3-bedroom-beachfront-cottage-suite/
#    Beautifully renovated, ground-floor Cottage with 2 bedrooms, expansive beachfront terrace with 2 fire pits, full kitchen, living room, 2 separate bedrooms, 2 baths, 2 sofa beds, and 2 fireplaces. 1,430 sq. ft. - 2 Bedrooms/2 Baths - Sleeps 6-10; 1 King Bed + 2 Queen Beds + 2 Sofa Beds
#
# 3. 3 Bedroom 2 Bath Suite | Lake Buena Vista Resort Suites
#    https://www.lbvorlandoresort.com/stay/3-bedroom-2-bath-suite
#    Amazing place two bedrooms with luxury bathrooms washer dryer balcony full kitchen with everything you need dining room living room, lots of tv channels. The pools were also great everything soo clean. PERFECT THANK YOU. My grandchildren loved the pirate pool and park, met with new friends. Only 15-20 minutes to the parks and great shops next door.
#
# 4. Three-Bedroom Suites - The Osthoff Resort
#    https://osthoff.com/resort-accommodations/three-bedroom-suites/
#    1 king-sized bed in master bedroom on main level, 1 queen-sized bed in the 2nd bedroom, 1 queen-sized bed in the 3rd bedroom, 2 complete bathrooms, master bathroom is handicap accessible and includes 1 one-person whirlpool tub, fully equipped kitchen, dining area, larger living area, queen-sized sleeper sofa, washer and dryer, gas fireplace, central air, and balcony.
#
# 5. Ambergris Caye Belize 3 Bedroom Suites | Oceanfront | Gardenview
#    https://www.xanaduislandresort.com/ambergris-caye-belize-three-bedroom-suites/
#    A staircase leads to the upper level with two bedrooms, each with their own en-suite bathroom. * The Garden View Three Bedroom suite , at 800 sq ft , is our smaller unit. While it can accommodate 6 people, its compact size and design make it more suitable for families and more comfortable for a maximum of 5 people.

# %%
from duckduckgo_search import DDGS
import requests
from bs4 import BeautifulSoup

def search_duckduckgo(query, num_results=5):
    with DDGS() as ddgs:
        results = list(ddgs.text(query, max_results=num_results))
        return results

def fetch_full_text(url):
    try:
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=10)
        response.raise_for_status()  # Raise an error for bad responses
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Extract main text content
        paragraphs = soup.find_all("p")  # Get all paragraph text
        full_text = "\n".join([p.get_text() for p in paragraphs])
        return full_text
    except requests.exceptions.RequestException as e:
        return f"Error fetching page: {e}"

query = "Hotels with 3 bedrooms, 2 bathrooms, beach-facing, pet-friendly"
search_results = search_duckduckgo(query)

for i, result in enumerate(search_results, 1):
    url = result['href']
    full_text = fetch_full_text(url)
    
    print(f"\n{i}. {result['title']}\n   {url}")
    print(f"Full Page Text:\n{full_text[:1000]}...")
# Out:
# 1. West Facing Beach House Pet Policy - BringFido
#    https://www.bringfido.com/lodging/641873
# Full Page Text:
#
# 														Make yourself at home! This property is equipped with the following “creature comforts” for your convenience.
#
#
#
#
#
#
#
#
# 					Stay out of the “dog house” by following these additional rules provided by the host. Guests are responsible for any damage caused by their pets.
#
#
#
# 					If you have any questions about this property, please
# 					contact the host.
#
#
#
#
#
#
#
#
#
#
#
#
# 				West Facing Beach House has received a rating of 4.9 out of 5 by
#
# 				85 guests
# 				on Vrbo.
#
#
#
#
#
#
# 									Be the first guest to
# 									submit a reviewsubmit a review
#
# 									on BringFido!
#
#
#
#
# 						We haven‘t received any photos of West Facing Beach House yet.
#
#
#
#
# 					Want to feature your creature? Upload a photo of your pet at West Facing Beach House!
#
#
# 				You can also share by using the hashtag #bringfido on Facebook, Twitter or Instagram.
#
#
# 					Be the first to ask a question about this...
#
# 2. Deluxe 3-Bedroom Oceanfront Hotel Suites | Acqualina Resort
#    https://www.acqualinaresort.com/accommodations/multi-bedroom-suites/deluxe-three-bedroom-oceanfront-hotel-suite
# Full Page Text:
# Most Commonly Searched Terms
# Resort & Residences on the Beach
# Acqualina features two Deluxe Three-Bedroom Oceanfront Suites offering an oasis of elegance and comfort. These spacious Miami hotel suites are ideal for discerning luxury travelers and upscale couples or family getaways.
# Both Deluxe Three-Bedroom Oceanfront Suites feature three bathrooms and private balconies with stunning views of the Atlantic Ocean. Each suite is equipped with a large living room, modern Italian design sofa sleeper, taupe lacquer credenza with integrated media connectivity, smoked glass and bronze metal coffee tables, signature style wingback club chairs and ottomans, ergonomic desk chairs, two sitting spaces including a media area with a high definition TV, a reading area with custom-built sofas, a writing desk, and a wine bar station. The kitchens are full gourmet with built-in Sub-Zero refrigerator/freezer, designer granite countertops, microwave, dishwasher, and stainless steel sink. The dining area se...
#
# 3. Oceanfront Three Bedroom Suite - Camelot by the Sea
#    https://www.camelotresort.com/rooms/oceanfront-three-bedroom-suite/
# Full Page Text:
# Room Code DM
# Room Code DM
# Our Oceanfront Three Bedroom Suites offer plenty of space and comfort. Each suite includes one king bed, one queen bed, two twin beds, and one full sleeper sofa. The private oceanfront balcony is attached to the living area, allowing extra room to relax. Dine-in using the many amenities in the fully-equipped kitchen. This suite also includes two bathrooms, a dishwasher, and washer and dryer.
# Photos represent sample accommodation. All units are individually owned and décor may vary.
#
# "
#                                   The hotel itself gave us so many things to do: indoor/outdoor pools, pool bar, right on the beach and free DVD rentals.
#                                   "
#
#
# "
#                                   Awesome customer service. Great prices. Nice and clean with ocean view. Highly recommend and will return.
#                                   "
#
#
# "
#                                   We love Camelot by the Sea! Love all of the amenities! It's in a great locat...
#
# 4. Three bedroom suites for 2-8 people in Miami Beach - Suiteness
#    https://www.suiteness.com/suites/united-states/florida/miami-beach/3_bedroom_suites
# Full Page Text:
#
# The only place to book connecting hotel rooms and suites. Here's how.
# There are 17 three bedroom suites in Miami Beach. The hotel that has the most 3 bedroom suites is W South Beach. You can fit up to 8 guests at hotels with an average star rating of
#
# Copyright 2025 Suiteness, Inc.
# Protected with SSL and Stripe
# How can we help you?...
#
# 5. Three Bedroom; 3 Bath Oceanfront Condo - Grand Atlantic Resort
#    https://www.grandatlanticresort.com/rooms/3Bedroom3BathOceanfrontCondo.cfm
# Full Page Text:
# 	Sea breezes, the sounds of the sea and breathtaking ocean views are yours to enjoy from the comfort of the 3 BR/3BA oceanfront condo.  The oceanfront master bedroom features a king size bed, private balcony access and master bath. The second bedroom also has a king size bed. The bedroom features two full size beds. With nearly 1300 sf, there is room for everyone in your group to enjoy personal space for rest and relaxation. The separate living room offers a pull out sleeper sofa for extra sleeping space, and also offers access to the oceanfront balcony.  This unit accommodates up to 10 people.
# > Virtual Tour
# Check Availabiltiy    View More Accommodations
# View More Accommodations
# Units are owned by individual homeowners. Furnishings and décor will vary by condo unit. Website photography is representative of the condos.
# All accommodations that are reserved through www.grandatlanticresort.com or 1.800.852.7032 are
# managed by onsite Grand Atlantic staff and offer the amenities that a...
